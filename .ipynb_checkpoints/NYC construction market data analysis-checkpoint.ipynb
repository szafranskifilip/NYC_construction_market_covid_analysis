# %%
import pandas as pd
import requests
import json
import matplotlib.pyplot as plt
import numpy as np

# Request API data from the NYC Open Data website 
base_url = "https://data.cityofnewyork.us/resource/ipu4-2q9a.json"
covid_url = "https://data.cityofnewyork.us/resource/rc75-m7u3.json"

# Check the API documentation to apply preliminary fileters and convert data to JSON:
new_url = base_url + "?$limit=38000" + '&' + "$where=filing_date like '2020%'"
results = requests.get(new_url).json()

covid_results = requests.get(covid_url, ).json()

# Convert results to pandas DataFrame
results_df = pd.DataFrame(results)
covid_df = pd.DataFrame(covid_results)

# %%
len(requests.get(new_url).json())
# Out:
# 30088

# %%
covid_df['date_of_interest'] = pd.to_datetime(covid_df['date_of_interest'])
covid_df['case_count'] = covid_df['case_count'].astype(str).astype(int)
covid_df
# Out:
#     date_of_interest  case_count hospitalized_count death_count
# 0         2020-02-29           1                 11           0
# 1         2020-03-01           0                  4           0
# 2         2020-03-02           0                 22           0
# 3         2020-03-03           2                 20           0
# 4         2020-03-04           5                 22           0
# ..               ...         ...                ...         ...
# 145       2020-07-23         160                 28           7
# 146       2020-07-24         142                 22           5
# 147       2020-07-25          53                  5           5
# 148       2020-07-26          34                  3           1
# 149       2020-07-27          10                  0           0
#
# [150 rows x 4 columns]

# %%
#Permit Issuance API data frame
pd.options.display.max_columns = None
results_df['filing_date'] = pd.to_datetime(results_df['filing_date'])
results_df
# Out:
#              borough    bin__    house__       street_name      job__  \
# 0           BROOKLYN  3052405        247    HANCOCK STREET  301885565
# 1             QUEENS  4619567     161-24        119TH ROAD  421924056
# 2             QUEENS  4140159     140-26           58TH RD  421908154
# 3      STATEN ISLAND  5803175        221      CANAL STREET  520279868
# 4          MANHATTAN  1005718        199   CHRYSTIE STREET  123178499
# ...              ...      ...        ...               ...        ...
# 30083       BROOKLYN  3144059       6301           4TH AVE  321760910
# 30084  STATEN ISLAND  5106818        121  VAN DUZER STREET  520367077
# 30085  STATEN ISLAND  5171258  16 GARAGE     EUGENE STREET  520338670
# 30086  STATEN ISLAND  5171261  28 GARAGE     EUGENE STREET  520338705
# 30087  STATEN ISLAND  5171254         28     EUGENE STREET  520355589
#
#       job_doc___ job_type  block    lot community_board zip_code bldg_type  \
# 0             01       A1  01834  00068             303    11216         1
# 1             01       NB  12248  00018             412    11434         1
# 2             01       A1  06404  00012             407    11355         1
# 3             01       NB  00527  00065             501    10304         2
# 4             04       NB  00426  00027             103    10002         2
# ...          ...      ...    ...    ...             ...      ...       ...
# 30083         01       DM  05809  00007             307    11220         2
# 30084         01       DM  00500  00022             501    10301         2
# 30085         01       NB  07774  00026             503    10309         1
# 30086         01       NB  07774  00033             503    10309         1
# 30087         01       NB  07774  00033             503    10309         1
#
#       residential permit_status filing_status permit_type permit_sequence__  \
# 0             YES        ISSUED       RENEWAL          AL                02
# 1             YES        ISSUED       RENEWAL          NB                02
# 2             YES        ISSUED       INITIAL          FO                01
# 3             NaN        ISSUED       RENEWAL          EQ                02
# 4             NaN        ISSUED       RENEWAL          PL                02
# ...           ...           ...           ...         ...               ...
# 30083         NaN        ISSUED       INITIAL          EQ                01
# 30084         NaN        ISSUED       INITIAL          DM                01
# 30085         NaN        ISSUED       INITIAL          NB                01
# 30086         NaN        ISSUED       INITIAL          NB                01
# 30087         YES        ISSUED       INITIAL          NB                01
#
#                  site_fill filing_date issuance_date expiration_date  \
# 0                     NONE  2020-01-16   2020-01-16       2020-11-21
# 1      USE UNDER 300 CU.YD  2020-01-15   2020-01-15       2020-09-28
# 2           NOT APPLICABLE  2020-01-16   2020-01-16       2020-12-08
# 3      USE UNDER 300 CU.YD  2020-01-15   2020-01-15       2021-01-14
# 4                      NaN  2020-01-15   2020-01-15       2021-01-14
# ...                    ...         ...           ...             ...
# 30083             OFF-SITE  2020-06-04   2020-06-05       2021-06-05
# 30084             OFF-SITE  2020-06-04   2020-06-05       2021-01-26
# 30085  USE UNDER 300 CU.YD  2020-06-04   2020-06-05       2021-06-05
# 30086  USE UNDER 300 CU.YD  2020-06-04   2020-06-05       2021-06-05
# 30087  USE UNDER 300 CU.YD  2020-06-04   2020-06-05       2020-12-22
#
#       job_start_date permittee_s_first_name permittee_s_last_name  \
# 0         2005-09-01                  DAVID         TOPRAKASHVILI
# 1         2019-11-15                KULBHAN           CHANDARBHAN
# 2         2020-01-16                  WENDY                    HE
# 3         2018-10-22                 MATTEO              NICOLOSI
# 4         2019-01-29                ANTHONY              GOFFREDO
# ...              ...                    ...                   ...
# 30083     2020-06-05                   TOBY            ROMANO, JR
# 30084     2020-06-05                   JOHN                BIANCO
# 30085     2020-06-05                   ALAN                BECKER
# 30086     2020-06-05                   ALAN                BECKER
# 30087     2020-06-05                   ALAN                BECKER
#
#        permittee_s_business_name permittee_s_phone__ permittee_s_license_type  \
# 0      DIAMOND CITY CONSTRUCTION          6463779443                       GC
# 1      ALL TIME CONSTRUCTION INC          7184193655                       GC
# 2           TGC CONSTRUCTION INC          3473684555                       GC
# 3              NICOLOSI BROS INC          7186054389                       GC
# 4      TRUE NORTH MECHANICAL LLC          7187688811                       MP
# ...                          ...                 ...                      ...
# 30083        BREEZE NATIONAL INC          7182548070                       GC
# 30084   GRANITE ENVIRONMENT, LLC          7189715572                       GC
# 30085        TCS CONTRACTING INC          7189661213                       GC
# 30086        TCS CONTRACTING INC          7189661213                       GC
# 30087        TCS CONTRACTING INC          7189661213                       GC
#
#       permittee_s_license__ owner_s_business_type non_profit  \
# 0                   0619949           CORPORATION          N
# 1                   0600268            INDIVIDUAL          N
# 2                   0618643            INDIVIDUAL          N
# 3                   0033687           CORPORATION          N
# 4                   0000768           PARTNERSHIP          N
# ...                     ...                   ...        ...
# 30083               0002689           CORPORATION          Y
# 30084               0618302            NYC AGENCY          N
# 30085               0613430           CORPORATION          N
# 30086               0613430           CORPORATION          N
# 30087               0613430           CORPORATION          N
#
#                   owner_s_business_name owner_s_first_name owner_s_last_name  \
# 0           247 HANCOCK RE HOLDING CORP            DMITRIY          PARDILOV
# 1                        NOT APPLICABLE              DAVID              LOJA
# 2                                   N/A          YANG RONG               LIN
# 3                       223 CANAL CORP.               MARK         KOPLOWITZ
# 4      SAGAMORE AK PROPERTY COMPANY LLC              SCOTT          KUMMINGS
# ...                                 ...                ...               ...
# 30083       METROPOLITAN NEW YORK SYNOD             DONALD            MCCOID
# 30084  HOUSING PRESERVATION & DEVELOPME            NYC HPD    REPRESENTATIVE
# 30085           EUGENE DEVELOPMENT, LLC               ALAN            BECKER
# 30086           EUGENE DEVELOPMENT, LLC               ALAN            BECKER
# 30087           EUGENE DEVELOPMENT, LLC               ALAN            BECKER
#
#       owner_s_house__ owner_s_house_street_name           city state  \
# 0                 247            HANCOCK STREET       BROOKLYN    NY
# 1              161-26                  119 ROAD         QUEENS    NY
# 2              140-26                   58TH RD       FLUSHING    NY
# 3                  12           LAWRENCE AVENUE       BROOKLYN    NY
# 4                  80       8 AVENUE, SUITE 708       NEW YORK    NY
# ...               ...                       ...            ...   ...
# 30083             475           RIVERSIDE DRIVE             NY    NY
# 30084             100               GOLD STREET       NEW YORK    NY
# 30085            2420          ARTHUR KILL ROAD  STATEN ISLAND    NY
# 30086            2420          ARTHUR KILL ROAD  STATEN ISLAND    NY
# 30087            2420          ARTHUR KILL ROAD  STATEN ISLAND    NY
#
#       owner_s_zip_code owner_s_phone__   dobrundate permit_si_no gis_latitude  \
# 0                11216      9177234526  2020-01-22       3730759    40.683010
# 1                11434      3472347296  2020-01-16       3730455    40.681303
# 2                11355      7187373988  2020-01-22       3730760    40.744544
# 3                11230      7182887977  2020-01-16       3730510    40.624726
# 4                10018      2124526077  2020-01-16       3730511    40.722048
# ...                ...             ...          ...          ...          ...
# 30083            10115      2126650732  2020-06-06       3761467    40.639050
# 30084            10038      2128637881  2020-06-06       3761546    40.635230
# 30085            10309      7189661213  2020-06-06       3761578    40.517010
# 30086            10309      7189661213  2020-06-06       3761585    40.516727
# 30087            10309      7189661213  2020-06-06       3761590    40.516727
#
#       gis_longitude gis_council_district gis_census_tract  \
# 0        -73.945964                   36              267
# 1        -73.782934                   28              288
# 2        -73.825551                   20            80301
# 3        -74.079764                   49               21
# 4        -73.991840                    1             3601
# ...             ...                  ...              ...
# 30083    -74.020275                   38              122
# 30084    -74.076588                   49               21
# 30085    -74.231336                   51            24401
# 30086    -74.231191                   51            24401
# 30087    -74.231191                   51            24401
#
#                                  gis_nta_name self_cert work_type  \
# 0                                     Bedford       NaN       NaN
# 1                                Baisley Park         N       NaN
# 2                             Queensboro Hill         N       NaN
# 3                          Stapleton-Rosebank         N        EQ
# 4                                   Chinatown         N        PL
# ...                                       ...       ...       ...
# 30083                        Sunset Park West         N        EQ
# 30084                      Stapleton-Rosebank         N       NaN
# 30085  Charleston-Richmond Valley-Tottenville         N       NaN
# 30086  Charleston-Richmond Valley-Tottenville         N       NaN
# 30087  Charleston-Richmond Valley-Tottenville         N       NaN
#
#       permit_subtype superintendent_first___last_name  \
# 0                NaN                              NaN
# 1                NaN                              NaN
# 2                NaN                              NaN
# 3                 FN                              NaN
# 4                NaN                              NaN
# ...              ...                              ...
# 30083             CH                              NaN
# 30084            NaN                      GLEN MURRAY
# 30085            NaN                              NaN
# 30086            NaN                              NaN
# 30087            NaN                              NaN
#
#       superintendent_business_name special_district_1  \
# 0                              NaN                NaN
# 1                              NaN                NaN
# 2                              NaN                NaN
# 3                              NaN                NaN
# 4                              NaN                NaN
# ...                            ...                ...
# 30083                          NaN                NaN
# 30084                          NaN                NaN
# 30085                          NaN                SRD
# 30086                          NaN                SRD
# 30087                          NaN                SRD
#
#       site_safety_mgr_s_first_name site_safety_mgr_s_last_name  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 30083                          NaN                         NaN
# 30084                          NaN                         NaN
# 30085                          NaN                         NaN
# 30086                          NaN                         NaN
# 30087                          NaN                         NaN
#
#       site_safety_mgr_business_name permittee_s_other_title hic_license  \
# 0                               NaN                     NaN         NaN
# 1                               NaN                     NaN         NaN
# 2                               NaN                     NaN         NaN
# 3                               NaN                     NaN         NaN
# 4                               NaN                     NaN         NaN
# ...                             ...                     ...         ...
# 30083                           NaN                     NaN         NaN
# 30084                           NaN                     NaN         NaN
# 30085                           NaN                     NaN         NaN
# 30086                           NaN                     NaN         NaN
# 30087                           NaN                     NaN         NaN
#
#       oil_gas act_as_superintendent
# 0         NaN                   NaN
# 1         NaN                   NaN
# 2         NaN                   NaN
# 3         NaN                   NaN
# 4         NaN                   NaN
# ...       ...                   ...
# 30083     NaN                   NaN
# 30084     NaN                   NaN
# 30085     NaN                   NaN
# 30086     NaN                   NaN
# 30087     NaN                   NaN
#
# [30088 rows x 59 columns]

# %%
import seaborn as sns

# %%
#PCOVID daily cases API data frame
covid_cases = pd.pivot_table(covid_df, index = 'date_of_interest', values = 'case_count', aggfunc = 'sum')
covid_cases
# Out:
#                   case_count
# date_of_interest
# 2020-02-29                 1
# 2020-03-01                 0
# 2020-03-02                 0
# 2020-03-03                 2
# 2020-03-04                 5
# ...                      ...
# 2020-07-23               160
# 2020-07-24               142
# 2020-07-25                53
# 2020-07-26                34
# 2020-07-27                10
#
# [150 rows x 1 columns]

# %%
covid_summary_df = pd.concat([covid_cases, total_by_day], axis=1)
covid_summary = covid_summary_df.fillna(value = 0.0)
covid_summary
# Out:
#             case_count  borough
# 2020-01-01         0.0     10.0
# 2020-01-02         0.0    331.0
# 2020-01-03         0.0    330.0
# 2020-01-05         0.0     15.0
# 2020-01-06         0.0    357.0
# ...                ...      ...
# 2020-07-23       160.0      0.0
# 2020-07-24       142.0      0.0
# 2020-07-25        53.0      0.0
# 2020-07-26        34.0      0.0
# 2020-07-27        10.0      0.0
#
# [206 rows x 2 columns]

# %%
total_by_day = pd.pivot_table(results_df, index = 'filing_date', values = 'borough', aggfunc='count')
total_by_day
# Out:
#              borough
# filing_date
# 2020-01-01        10
# 2020-01-02       331
# 2020-01-03       330
# 2020-01-05        15
# 2020-01-06       357
# ...              ...
# 2020-06-01       220
# 2020-06-02       301
# 2020-06-03       250
# 2020-06-04       382
# 2020-06-05       442
#
# [151 rows x 1 columns]

# %%
jobtype_breakdown = pd.pivot_table(results_df, index = 'filing_date', columns = 'job_type', 
                                   values = 'bin__', aggfunc = 'count')
jobtype_breakdown.fillna(value = 0.0)
# Out:
# job_type       A1     A2    A3    DM    NB   SG
# filing_date
# 2020-01-01    1.0    3.0   0.0   0.0   6.0  0.0
# 2020-01-02   31.0  238.0   8.0   5.0  49.0  0.0
# 2020-01-03   49.0  196.0  12.0   7.0  66.0  0.0
# 2020-01-05    0.0   14.0   0.0   0.0   1.0  0.0
# 2020-01-06   44.0  223.0  16.0   3.0  71.0  0.0
# ...           ...    ...   ...   ...   ...  ...
# 2020-06-01   33.0  139.0   6.0   0.0  42.0  0.0
# 2020-06-02   22.0  234.0  21.0   0.0  24.0  0.0
# 2020-06-03   42.0  149.0  22.0   1.0  36.0  0.0
# 2020-06-04   36.0  256.0  21.0  15.0  54.0  0.0
# 2020-06-05   36.0  283.0  15.0  13.0  95.0  0.0
#
# [151 rows x 6 columns]

# %%
borough_breakdown = pd.pivot_table(results_df, index = 'filing_date', columns = 'borough', 
                                   values = 'bin__', aggfunc = 'count')
borough_breakdown.fillna(value = 0.0)
# Out:
# borough      BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND
# filing_date
# 2020-01-01     4.0       2.0        2.0     2.0            0.0
# 2020-01-02    29.0     164.0       75.0    42.0           21.0
# 2020-01-03    26.0     101.0      114.0    66.0           23.0
# 2020-01-05     3.0       3.0        3.0     5.0            1.0
# 2020-01-06    24.0      84.0      135.0    92.0           22.0
# ...            ...       ...        ...     ...            ...
# 2020-06-01    40.0      66.0       72.0    41.0            1.0
# 2020-06-02    33.0      84.0      114.0    53.0           17.0
# 2020-06-03    21.0      67.0      110.0    29.0           23.0
# 2020-06-04    30.0     116.0      165.0    49.0           22.0
# 2020-06-05    45.0     156.0      148.0    60.0           33.0
#
# [151 rows x 5 columns]

# %%
resi_count_df = pd.pivot_table(results_df, index = 'filing_date', columns = results_df['residential'].fillna(value = 'NO'), values = 'bin__', aggfunc = 'count')
resi_count = resi_count_df.fillna(value = 0.0)
resi_count
# Out:
# residential     NO    YES
# filing_date
# 2020-01-01     2.0    8.0
# 2020-01-02   153.0  178.0
# 2020-01-03   177.0  153.0
# 2020-01-05     0.0   15.0
# 2020-01-06   144.0  213.0
# ...            ...    ...
# 2020-06-01   105.0  115.0
# 2020-06-02   210.0   91.0
# 2020-06-03   106.0  144.0
# 2020-06-04   150.0  232.0
# 2020-06-05   154.0  288.0
#
# [151 rows x 2 columns]

# %%
#Total number of permits issued in 2020 in each borough
plt.figure(figsize=(10, 8))
sns.countplot(x='borough', data = results_df, order = results_df['borough'].value_counts().index, palette ="Blues_d")

# %%
all_chart2 = borough_breakdown.fillna(value = 0.0).plot(kind='line', figsize = (18,10), lw = 1)

# %%
total_by_day.reset_index().plot(kind='line', x='month', y='borough', figsize = (18,10))

# %%
fig = plt.figure(figsize=(15, 7))
ax = fig.add_axes([0, 0, 1, 1])


ax.plot(resi_count['YES'], linewidth=2)
ax.plot(resi_count['NO'], linewidth=1)


plt.title('Residential')
# Out:
# Text(0.5, 1.0, 'Residential')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize = (15,7))

axes[0].plot(resi_count['YES'], linewidth=2)
axes[1].plot(resi_count['NO'], linewidth=1)
axes[0].set_title('Residential')
axes[1].set_title('Other')

plt.tight_layout()
plt.show()

# %%
jobtype_breakdown.fillna(value = 0.0).plot(kind='line', figsize = (18,10), lw= 1.5)
plt.title('PERMIT ISSUANCE - JOB TYPE BREAKDOWN')
plt.grid(True)
plt.rc('grid', linestyle="--", color='grey', alpha=0.8)

# %%
fig = plt.figure(figsize=(18, 7))

line_weight = 1.5
alpha = 0.8

ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes()

plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15, color='C0', alpha=1)

plt.grid(True)
plt.rc('grid', linestyle="--", color='grey', alpha=0.6)

# This joins the x-axis
ax2 = ax1.twinx()


lns1 = ax1.plot(covid_summary['borough'], color='C0', lw=line_weight, alpha=alpha, label='permit filings')
lns2 = ax2.plot(covid_summary['case_count'], color='C1', lw=line_weight, alpha=alpha, label='case count')
plt.yticks(fontsize=15, color='C1', alpha=1)

# Solution for having two legends
leg = lns1 + lns2
labs = [l.get_label() for l in leg]
ax1.legend(leg, labs, loc=0, fontsize=15)

#Plot title and tile font size
plt.title('PERMIT ISSUANCE VS. NEW COVID CASES', fontsize=15)


        
plt.show()

# %%
plt.figure(figsize=(8, 12))
plt.title('# of New Permit Filings')

ax = sns.heatmap(borough_breakdown.fillna(value = 0.0))
ax.set_yticklabels([t.get_text().split("T")[0] for t in ax.get_yticklabels()])

ax
